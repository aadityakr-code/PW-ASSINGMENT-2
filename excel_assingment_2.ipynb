# %% [markdown]
# # QUESTION 1
# Data cleaning is crucial because:
#  1) improve accuracy
#     clean data leades to correct insights and better decision making.
#  2) helps in better analysis
#     clean and organised data allows algorithms and charts to work
#  3) improves modle performance
#     in machine learning clean data = better predictions
#
# . in simple words
#   better cleaning makes your dataset usable
#   ,accurate and trustworthy.
#
#
#   -> Major consequences of using unclean data.
#   1. incorrect conclusion
#     dirty data leads to wrong patterns and false insights.
#   2. poor decision making
#     bussiness may take bad decisions based on inaccurate results.
#   3. inconsistent result
#     duplicate or missing values can give unstable or unpredictable results.
#   4. financial loss
#   wrong prediction or wrong decision can directly cause monetary loss
#
#   ->Common steps involved in data cleaning & organizing data are as follows:
#   1. data importing.
#   2. data inspection.
#   3. handling missing values.
#   4. removing duplicates.
#   5. correcting data types.
#   6. standardizing formats.
#   7. creating derived columns.
#   8. final quality check.
#
#
# # QUESTION 2
#  Step by step approach
# - STEP 1: Create the dataset
# enter the data into a lable or load it into a data frame.
# - STEP 2: Sort by department (a-z)
# alphabetically, HR comes before IT.
# so Parnav (HR) appers first.
# - STEP 3: Sort within each department by salary (largest - smallest)
#   IN HR: only parnav so no change
#   IN IT: two employes -sonu (4000) and rahul (2000) sort by salary 4000 comes before 2500.
# - CONCLUSION
# The dataset is sort first by department alphabetically, then each department is sorted by salary in desecnding order, giving a clearly organised and meaningful output.
#
# # QUESTION 3
# 1. TRIM Function
# remove extra space from text, except for a single space between words.
# 2. LEFT Function
# extract a specific number of characters from the left side of single string.
# 3. RIGHT Funcion
# extract chracters from the right side of text strings.
# 4. MID Functions
# extract chracters from the middle of text strings (you choose starting point & length).
# 5. CONCAT OR (CONCATENATE)
# joins (cobines) two or more text values together.
#
# # QUESTION 4
# TODAY() helps make dataset dynamic, automated, and time-aware, which improves reporting , schduling, tracking, and data accuracy.
#
# # QUESTION 5
# (a) input message (when user selects a quantity cell) step by step approach:
# 1. select the cell in the quantity column.
# 2. go to data - data validation
# 3. in the criteria section, choose: number - between - 1 and 10
# 4. enable show help text.
# 5. type the following input message: "please enter a whole number between 1 and 10".
# 6. click save.
# - this ensure that whenever a user selects a quantity cell, the message appers explaining what to enter.
#
# (b) error alert (when user enters invalid number) step by step approach:
# 1. with the same quantity cell selected, open data validation again.
# 2. make sure criteria = number between 1 and 10 is selected.
# 3. turn on reject input, so vailid number cannot be entered.
# 4. in the help text/Error message box, type: "invaid input! the quantity must be a whole number between 1 and 10".
# 5. click save.
# - Now if a user name enters a number less than 1, greater than 10, or not a whole number, the error will appear.
#
# # QUESTION 6
# (a) =LEFT("ExcelTipsAreGreat", 5)
# will give answer = Excel
#
# (b) =RIGHT("DataAnalysis.xlsx", 4)
# will give answer = xlsx
#
# (c) =MID("ExcelTipsAreGreat", 6, 4)
# will give ansewer = Tips
#
# (d) =len("Hello World!")
# will give answer = 12
#
# (e) =MID("12345-67890-ABCDE", 7, 6)
# will give answer = 67890-
#
# # QUESTION 7
# (a) =CONCAT("HELLO"," ", "WORLD")
# RESULT = Hello World
#
# (b) =TEXT JOIN(", ", TRUE, "Apple", "Banana", "Cherry")
# RESULT = Apple, Banana, cherry
#
# (c) ="2025" & ": " & " Excel Functions"
# RESULT = 2025: Excel Functions
#
# (d) =TEXT JOIN(" , ",TRUE, A1:A5)
# TEXTJOIN joins all values in cells A1 to A5 with commas in between.
#
# (e) =A1 & " " & B1
# This joins the name (A1), a space, and the last name (B1). copy down to fill the entire column.
#
# # QUESTION 8
# (a) 1. TODAY()
# - Returns only the current date (no time).
# - Updates automatically everyday
#  2. NOW()
# - Use TODAY() when calculating age, due dates, days remaining, or deadlines.
# - Use NOW() When you need a timestamp including time (attendance logs, time tracking).
#
# (b) =A1 - TODAY()
# RESULT = This subtract today's date from the target date.
#
# (c) =TEXT(NOW(), "mm/dd/yyyy hh:mm AM/PM")
# TEXT formats the NOW() output into the required date-time format.
#
# (d) The valueb update automatically to the new current date every time the workbook is opened or recalculated.
#
# (e) ctrl + ;
# this inserts the current date as fixed value (not a fourmula), so it will not update.
